# %%
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from ucimlrepo import fetch_ucirepo 
import pandas as pd
import sys
sys.path.append("../")
import models
from utils.training import train_meta_model, train_gp
from utils.bo_data import noisy_function, generate_noisy_dataset
from utils.data_utils import ctxt_trgt_split

torch.set_default_dtype(torch.float64)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plt.scatter(*generate_noisy_dataset(dim=1, n=500, std=1.0, limit=5, func='sphere'))
plt.ylim([-7.0, 7.0])
plt.show()
